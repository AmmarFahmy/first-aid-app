# %%
# !pip install pytube

# %%
from pytube import Search

s = Search('Apex Legends gameplay')
for video in s.results[:5]:
    print(video.title, video.watch_url)
# Out:
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Apex Legends gameplay
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Apex Legends gameplay
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Apex Legends (2021) - Gameplay (PC UHD) [4K60FPS] https://youtube.com/watch?v=UPtoIy-oPWQ
# Becoming the Rank #1 Ash in Apex Legends... https://youtube.com/watch?v=Kt-Twa-IwLs
# SOLO Ash INSANE 29 KILLS and 5K Damage Apex Legends https://youtube.com/watch?v=7tQa1qAFkKA
# INSANE New ASH 32 KILLS and 7K Damage Apex Legends Gameplay https://youtube.com/watch?v=FOlTRnYOStc
# Mirage 34 KILLS and 7K Damage Intense Gameplay Apex Legends https://youtube.com/watch?v=QmxpUrNr88E

# %%
video
# Out:
# <pytube.__main__.YouTube object: videoId=Jr7jtlPA-uQ>
